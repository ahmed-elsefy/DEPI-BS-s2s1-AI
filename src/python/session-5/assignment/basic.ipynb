# %%
class Student :
    _id_counter = 1
    def __init__(self,name):
        self.student_id = 
        pass

# %%
class Student:
    _id_counter = 1 #Class Attribute
    def __init__(self,name):
        self.Student_id = Student._id_counter #Note what is this
        Student._id_counter+=1
        self.name = name

# %%
s1 = Student("Ahmed")
print(s1)
# Out:
# <__main__.Student object at 0x00000140A0F638C0>

# %%
class Student:
    _id_counter = 1 #Class Attribute
    def __init__(self,name):
        self.Student_id = Student._id_counter #Note what is this
        Student._id_counter += 1
        self.name = name
    def __str__(self):
        return f"student id : {self.Student_id} name : {self.name}"
    def __repr__(self) -> str :
        return f"student id : {self.Student_id} name : {self.name}"

# %%
s1 = Student("Ahmed")
repr(s1)
str(s1)
print(s1)
# Out:
# student id : 2 name : Ahmed

# %%
class Student:
    _id_counter =1 # class attribute
    def __init__(self, name):
        self.student_id = Student._id_counter
        Student._id_counter += 1
        self.name = name
        self.grades ={}
        self.enrolled_courses = []
    def __str__(self):
        return f"student ID :{self.student_id} name :{self.name}, Grades :{self.grades}, Courses :{self.enrolled_courses}"
    def __repr__(self) -> str:
        return f"student ID :{self.student_id} name :{self.name}, {self.enrolled_courses},{self.grades}"
    def add_grade(self,course_id,grade ):
        if not 0 <= grade <= 100  :
            raise ValueError("grase must be between 0 and 100")
        self.grades[course_id] = grade

    def enroll_in_course(self,course):
        if course in self.enrolled_courses:
            raise ValueError("student already enrolled in thhis course")
        else:
            self.enrolled_courses.append(course)

# %%
s1 = Student("Ahmed")
repr(s1)
s1.add_grade("math",90)
s1.enroll_in_course("cs")
str(s1)
# Out:
# "student ID :1 name :Ahmed, Grades :{'math': 90}, Courses :['cs']"

# %%
class Course :
    _id_counter = 1 
    def __init__(self,name,):
        self.course_id = course._id_counter
        course._id_counter += 1
        self.name = name
        self.enrolled_students = []

# %%
import unittest
 
class TestStudent(unittest.TestCase):
   
   
    def setup(self):
        self.student = Student("Faris")
       
    def test_creation(self):
        self.assertEqual(self.student.name, "Faris")
    def test_add_grade(self):
        self.student.add_grade(1, 90)
        self.assertEqual(self.student.grades[1], 90)
    def test_enroll_in_course(self):
        course = Course("Math")
        self.student.enroll_in_course(c)
        self.assertIn(course, self.student.enroll_in_courses)
        
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# EEE
# ======================================================================
# ERROR: test_add_grade (__main__.TestStudent.test_add_grade)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\XPS STORE\AppData\Local\Temp\ipykernel_21764\491327547.py", line 12, in test_add_grade
#     self.student.add_grade(1, 90)
#     ^^^^^^^^^^^^
# AttributeError: 'TestStudent' object has no attribute 'student'
#
# ======================================================================
# ERROR: test_creation (__main__.TestStudent.test_creation)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\XPS STORE\AppData\Local\Temp\ipykernel_21764\491327547.py", line 10, in test_creation
#     self.assertEqual(self.student.name, "Faris")
#                      ^^^^^^^^^^^^
# AttributeError: 'TestStudent' object has no attribute 'student'
#
# ======================================================================
# ERROR: test_enroll_in_course (__main__.TestStudent.test_enroll_in_course)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\XPS STORE\AppData\Local\Temp\ipykernel_21764\491327547.py", line 15, in test_enroll_in_course
#     course = Course("Math")
# TypeError: Course() takes no arguments
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.009s
#
# FAILED (errors=3)

# %%
class Course:
    _id_counter = 1

    def _init_(self, name):
        self.course_id = Course._id_counter
        Course._id_counter += 1
        self.name = name
        self.enrolled_students = []  # قائمة الطلاب المسجلين في هذا الكورس

    def _str_(self):
        return f"Course ID: {self.course_id}, Name: {self.name}, Enrolled: {len(self.enrolled_students)}"

    # تسجيل الطالب في الكورس
    def enroll_student(self, student):
        if student not in self.enrolled_students:
            self.enrolled_students.append(student)
            print(f"Student {student.name} enrolled successfully in {self.name}.")
        else:
            print(f"Student {student.name} is already enrolled in {self.name}.")

    # إزالة الطالب من الكورس الحالي
    def remove_student(self, student):
        if student in self.enrolled_students:
            self.enrolled_students.remove(student)
            print(f"Student {student.name} removed from {self.name}.")
        else:
            print(f"Student {student.name} is not enrolled in {self.name}.")

# %%
s1 = Student("Ahmed")
s1.enrolled_courses.append("Math")
s1.add_grade("math",90)
s1.enroll_in_course("cs")
str(s1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 s1 = Student("Ahmed")
#       2 s1.enrolled_courses.append("Math")
#       3 s1.add_grade("math",90)
#       4 s1.enroll_in_course("cs")
#
# NameError: name 'Student' is not defined

# %%
class Task1:
    """
    Task1 class handles the operation of checking whether a number is even or odd.
    
    Attributes:
        number (int): The number to be checked.
    """
    def __init__(self, number: int):
        """
        Initializes the Task1 object with a given number.
        """
        self.number = number

    def check_even_odd(self) -> str:
        """
        Determines whether the number is even or odd.
        
        Returns:
            str: 'Even' if the number is even, otherwise 'Odd'.
        """
        if self.number % 2 == 0:
            return "Even"
        return "Odd"


t1_obj = Task1(10)
result_1 = t1_obj.check_even_odd()
print(f"Task 1 Result (Number 7): {result_1}")
# Out:
# Task 1 Result (Number 7): Even
