# %%
list_1 .ensert(0,"nlp")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 list_1 .ensert(0,"nlp")
#
# AttributeError: 'list' object has no attribute 'ensert'

# %%
list_1 = ["depi" , "ml", "genai"]
list_1 .append("deep learning")
print(list_1)
# Out:
# ['depi', 'ml', 'genai', 'deep learning']

# %%
list_one = [1,2,3,4,"Depi","Machine learning", True,[1,2,3,"true",["ml","dl","llm"]]]

# %%
list_2 = ["depi", "ml","dl"]
list_2 .pop()
print(list_2)
# Out:
# ['depi', 'ml']

# %%
del list_2
print(list_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 del list_2
# ----> 2 print(list_2)
#
# NameError: name 'list_2' is not defined

# %%
name =input("Enter your Name : ")
new_namelist = list(name)
age = input("enter your age :")
print(f"my name is {name}, my age is {age}")
# Out:
# my name is ahmed, my age is 20

# %%
input_list =["amit","learning","python","Machine learning ","data science ","deep learning"]
item = input("enter item you want to remove :")
input_list .remove(item)
print(input_list)
# Out:
# ['learning', 'python', 'Machine learning ', 'data science ', 'deep learning']

# %%
my_list =[1,2,3]
index_of_2 =my_list .index(2)

# %%
list_5 =[4,7,7,2,1]
my_list .

# %%
my_list =[1,2,3]
my_list.reverse()
print(my_list)
# Out:
# [3, 2, 1]

# %%
my_list =[1,2,3]
my_list.clear()
print(my_list)
# Out:
# []

# %%
tuble_1 = (1,2,3)
print (type(tuble_1[0]))
# Out:
# <class 'int'>

# %%
tuble_1 = (1,2,3)
tuble_1[0] ="depi"

# %%
x = {1,2,3}
type(x)
# Out:
# set

# %%
x2 ={1:"gourge"}
type(x2)
# Out:
# dict

# %%
a = {1,2,3}
b = {3,4,5}
print (a| b)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(a .intersection(b))
# Out:
# {3}

# %%
dict_1 ={"key 1": 12.5, "key2":5}
dict_1["key 1"] = "Depi"
print(dict_1)
# Out:
# {'key 1': 'Depi', 'key2': 5}

# %%
value_1 = [('a',1),('b',2)]
dict_2 = dict(value_1)
print(type(dict_2))
# Out:
# <class 'dict'>

# %%
num = int(input("enter your id :"))
print(type(num))
# Out:
# <class 'int'>

# %%
5//2
# Out:
# 2

# %%
num_1 =int(input("enter first num"))
num_2 =int(input("enter second num"))

print(f"sum : {num_1 + num_2}")
print(f"sub : {num_1 - num_2}")
print(f"multiplication : {num_1 * num_2}")
print(f"division : {num_1 / num_2}")
# Out:
# sum : 12
# sub : -2
# multiplication : 35
# division : 0.7142857142857143

# %%
a = 200
b = 33 
if b > a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x = 5
y = 10
if x > 0 and y > 0 :
    print ("both graeter than zero")
# Out:
# both graeter than zero

# %%
score = float(input("enter your degree"))
if 0 <= score <= 100:
    if score >= 90:
        grade ='A'
    elif score >= 80:
        grade ='b'
    elif score >= 70:
        grade ='c'
    elif score >= 60:
        grade = 'd'
    else:
        grade ='f'        

        print(f"the grade is : {grade}")
else:
        print(f"invalid degree")
