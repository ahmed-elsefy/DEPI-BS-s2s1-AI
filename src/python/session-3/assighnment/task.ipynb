# %%
def print_multiplication_table(num):
    for i in range(1, 11):
        print(f"{num} * {i} = {num * i}")

print_multiplication_table(9)
# Out:
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
# 9 * 10 = 90

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def twin_primes(limit):
    for n in range(2, limit - 2):
        if is_prime(n) and is_prime(n + 2):
            print(f"{n} and {n + 2}")

twin_primes(1000)
# Out:
# 3 and 5
# 5 and 7
# 11 and 13
# 17 and 19
# 29 and 31
# 41 and 43
# 59 and 61
# 71 and 73
# 101 and 103
# 107 and 109
# 137 and 139
# 149 and 151
# 179 and 181
# 191 and 193
# 197 and 199
# 227 and 229
# 239 and 241
# 269 and 271
# 281 and 283
# 311 and 313
# 347 and 349
# 419 and 421
# 431 and 433
# 461 and 463
# 521 and 523
# 569 and 571
# 599 and 601
# 617 and 619
# 641 and 643
# 659 and 661
# 809 and 811
# 821 and 823
# 827 and 829
# 857 and 859
# 881 and 883

# %%
def prime_factors(n):
    factors = []
    divisor = 2
    while n > 1:
        while n % divisor == 0:
            factors.append(divisor)
            n //= divisor
        divisor += 1
    return factors

print(prime_factors(56))
# Out:
# [2, 2, 2, 7]

# %%
def dec_to_bin(n):
    if n == 0:
        return "0"
    binary_str = ""
    while n > 0:
        binary_str = str(n % 2) + binary_str
        n //= 2
    return binary_str

print(dec_to_bin(11))
# Out:
# 1011

# %%
def is_perfect(n):
    if n <= 0:
        return False
    sum_divisors = 0
    for i in range(1, n):
        if n % i == 0:
            sum_divisors += i
    return sum_divisors == n

def perfect_nums(start, end):
    for num in range(start, end + 1):
        if is_perfect(num):
            print(num)

perfect_nums(0, 100)
# Out:
# 6
# 28

# %%
import os
import random

def thanos_project(folder_path="universe", num_files=10):
    """
    Creates a folder, generates files inside it, and deletes a random half of them.

    :param folder_path: path of the folder to create and manage
    :type folder_path: str
    :param num_files: number of files to generate inside the folder
    :type num_files: int

    :return: None
    :rtype: None
    """
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder created: {folder_path}")

    for i in range(1, num_files + 1):
        file_path = os.path.join(folder_path, f"file_{i}.txt")
        with open(file_path, "w") as f:
            f.write("Hi, Iam Ahmed")
    print(f"Successfully created {num_files} files.")

    files = os.listdir(folder_path)
    print(f"Number of files before deletion: {len(files)}")

    half_count = len(files) // 2
    files_to_delete = random.sample(files, half_count)

    for file_name in files_to_delete:
        file_to_remove = os.path.join(folder_path, file_name)
        os.remove(file_to_remove)

    print(f"Randomly deleted {half_count} files.")

    remaining_files = os.listdir(folder_path)
    print(f"Number of remaining files: {len(remaining_files)}")
    print("Remaining files are:", remaining_files)

thanos_project()
# Out:
# Successfully created 10 files.
# Number of files before deletion: 10
# Randomly deleted 5 files.
# Number of remaining files: 5
# Remaining files are: ['file_10.txt', 'file_2.txt', 'file_5.txt', 'file_8.txt', 'file_9.txt']

# %%
def calculator():
    """
    Executes a basic calculator program that performs addition, subtraction,
    multiplication, and division with input validation and a continuous loop.

    :return: None
    :rtype: None
    """
    while True:
        print("\nSelect Operation:")
        print("1. Addition")
        print("2. Subtraction")
        print("3. Multiplication")
        print("4. Division")
        print("5. Exit")

        choice = input("Enter choice (1-5): ")

        if choice == '5':
            print("Thank you for using the calculator. Goodbye!")
            break

        if choice not in ['1', '2', '3', '4']:
            print("Invalid operation choice. Please try again.")
            continue

        while True:
            try:
                num1 = float(input("Enter first number: "))
                break
            except ValueError:
                print("Invalid input! Please enter a valid number.")

        while True:
            try:
                num2 = float(input("Enter second number: "))
                break
            except ValueError:
                print("Invalid input! Please enter a valid number.")

        if choice == '1':
            result = num1 + num2
            print(f"The result of adding {num1} and {num2} is {result}.")
        elif choice == '2':
            result = num1 - num2
            print(f"The result of subtracting {num2} from {num1} is {result}.")
        elif choice == '3':
            result = num1 * num2
            print(f"The result of multiplying {num1} and {num2} is {result}.")
        elif choice == '4':
            if num2 == 0:
                print("Error: Division by zero is not allowed.")
            else:
                result = num1 / num2
                print(f"The result of dividing {num1} by {num2} is {result}.")

        again = input("Do you want to perform another calculation? (yes/no): ").lower()
        if again != 'yes':
            print("Thank you for using the calculator. Goodbye!")
            break

calculator()
# Out:
# Select Operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# The result of adding 5.0 and 3.0 is 8.0.
# Thank you for using the calculator. Goodbye!
