# %%
name = "Amit learning"
print(name[0:4:1])
# Out:
# Amit

# %%
print ("Enter your name : ")
x = input() 

print ("enter your age ")
y = int(input())

print ("what is your couse name :")
z = input()

output_text = f"my name is  {x} , my age is {y} ,the course name is  {z}"

print ("output_text")
# Out:
# Enter your name :
